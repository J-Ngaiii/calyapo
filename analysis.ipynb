# %%
import pandas as pd
from pathlib import Path
from calyapo import DATA_PATHS

# %%
raw_path = Path(DATA_PATHS['IGS']['raw']) / "igs_20240819.dta"
raw = pd.read_stata(raw_path, convert_categoricals=False)

# %%
raw.head(5)
# Out:
#    AD  AGE  age_tab  asian  black  CD  CNTY  CompletionDate  F12  F13  ...  \
# 0  12   42      3.0    NaN    NaN   2    21               1    2    1  ...
# 1  10   22      1.0    NaN    NaN   7    34               1    2    2  ...
# 2  13   45      3.0    NaN    NaN   9    39               1    1    1  ...
# 3  80   33      2.0    1.0    NaN  52    37               1    2    2  ...
# 4   6   32      2.0    NaN    NaN   7    34               1    2    2  ...
#
#     Q9  region  region_coarse   RZIP  RZIP4  SD  SEX  URBANICITY        w1  \
# 0  5.0       1              1  94903   3234   2  1.0         2.0  0.481962
# 1  4.0       3              3  95820   2342   8  2.0         3.0  4.199734
# 2  4.0       4              3  95204   1105   5  2.0         2.0  0.582903
# 3  4.0       9              8  92154   1457  18  1.0         3.0  4.438886
# 4  1.0       3              3  95816   7030   8  2.0         3.0  1.279516
#
#    white
# 0    1.0
# 1    1.0
# 2    1.0
# 3    NaN
# 4    NaN
# ...
